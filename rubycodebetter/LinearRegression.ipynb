# %%
# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt


import pandas as pd
import random

from IPython.display import HTML, display
#import tabulate

def PrintXL(*arg):
    html="<span style='font-size: 22px;font-weight:700'>"
    for a in arg:
        html += str(a)
    html +="</span>"
    display(HTML(html))
    
def PrintL(*arg):
    html="<span style='font-size: 18px;font-weight:700'>"
    for a in arg:
        html += str(a)
    html +="</span>"
    display(HTML(html))
    
def PrintM(*arg):
    html="<div width='100%'' style='font-size: 15px;font-weight:500; line-height:14px'>"
    for a in arg:
        html += str(a)
    html +="</div>"
    display(HTML(html))
    
import math
sigmoid = lambda y: 1.0/(1+math.exp(-y))

# %% [markdown]
# ## Hypothesis Function For One Feature
# <img src="./files/hypothesis.png">
# <br><br>
#
# ## Hypothesis Function for Many Features
# <img src="./files/bighyp.png">
# <br><br>
#
# ## Features (x) and Weights (theta)
# <img src="./files/weightsfeatures.png">
# <br><br>
#
# θ's are actually the weights assigned to a particular feature. Not all parameters affect the hypothesis function equally.

# %% [markdown]
# # Cost Function
#
# <img src="./files/costfunction.png">

# %%
# b and m are weights
# X are features (ex sq ft of house)
# Y are answers (ex price of house)
# hypothesis =    hθ = mx+b   ..same as..   hθ = θ(0) + θ(1)x
def costFunction(b,m, X, Y):
    sumOfSE=0
    n = float(len(X))  # I use m above but whatev
    for x,y in zip(xs,ys):
        hypothesis = m*x+b
        error = y - hypothesis
        squaredError = error**2
        sumOfSE += squaredError
    cost = 1/n * sumOfSE
    return cost;

# %% [markdown]
# ### Update Weights
# ### α = learning rate
#
# <img src="./files/gradientdescent.png">
# <br><br>
#
# You have to take the partial derivate of the cost function, base on the theta you are currently updating.<br>
# You have to update all thetas at the same time.  The update of one theta cannot interfere with the update of another.<br>

# %%
# don't worry about any of this
# https://scriptverse.academy/tutorials/python-matplotlib-plot-straight-line.html
def elPlotto(m,b,xs,ys,show):
    x = np.linspace(0,5,65)
    y=m*x+b
    plt.plot(xs,ys, '.')
    plt.plot(x,y,'-r')
    if show is True:
        plt.show()

## this code is written to be human readable and look like the formulas.
# other versions of this would try to be effecient for Python, not a humans
# b and m are weights
# X are features (ex sq ft of house)
# Y are answers (ex price of house)
# hypothesis =    hθ = mx+b   ..same as..   hθ = θ(0) + θ(1)x
def updateWeights(b,m, xs, ys, learning_rate):
    #print(X,Y,xs,ys)
    bDerivativeSum=0
    mDerivativeSum=0
    n = float(len(xs))
    i= 1
    w1adj="w1 := w1 - alpha * 1/" + str(n) + " * ( "
    w0adj="w0 := w0 - alpha * 1/" + str(n) + " * ( "
    for x,y in zip(xs,ys):
        hypothesis = m*x+b
        error = y - hypothesis
        # Calculate partial derivatives
        # -2(y - (mx + b))
        bDerivativeSum +=  - (error)      
        # -2(y - (mx + b)) * x
        mDerivativeSum +=  - (error * x)
        print(f"Hypothesis{i}: {hypothesis}\nError{i}: {error}\n")
        w0adj += f"{error} * 1 + "
        w1adj += f"{error} * {x} + "
        i = i + 1;
    cost=costFunction(b,m,xs,ys)

    # We subtract because the derivatives point in direction of steepest ascent
    # equation to adjust the weights is 
    #   b = b - learningRate*sum
    #   m = m - learningRate*sum * x
    # They must be updated simultaneously, which is why we use derivative variables
    b -= 2/n * bDerivativeSum * learning_rate
    m -= 2/n * mDerivativeSum * learning_rate
   
    print(f"{w0adj} ) = {b}")
    print(f"{w1adj} ) = {m}")
    print(f"Cost function = {cost}")
    print(f"\n\n")
    return [b,m,cost]

# some of the below is just restated for ease of reading
# alpha is the learning rate
b=0  
m=0
alpha=0.02
cost=0
xs = np.array([1, 2, 3])
ys = np.array([5, 7, 9])
iterations=1000

elPlotto(m,b,xs,ys,False)

for i in range(iterations):
    print(f"---- iteration {i} ----")
    [b,m,cost] = updateWeights(b,m,xs,ys,alpha)
    if (i%2==0):
        elPlotto(m,b,xs,ys,False)


PrintL("Results for Weights:")
PrintM('θ(0) aka b = ',b, '<br>θ(1) aka m = ',m)
PrintL("Final Cost at Last Iteration:")
PrintM("(Should be small #)")
PrintM("Cost = ", cost)
# Out:
# ---- iteration 0 ----
# Hypothesis1: 0
# Error1: 5
#
# Hypothesis2: 0
# Error2: 7
#
# Hypothesis3: 0
# Error3: 9
#
# w0 := w0 - alpha * 1/3.0 * ( 5 * 1 + 7 * 1 + 9 * 1 +  ) = 0.28
# w1 := w1 - alpha * 1/3.0 * ( 5 * 1 + 7 * 2 + 9 * 3 +  ) = 0.6133333333333333
# Cost function = 51.666666666666664
#
#
#
# ---- iteration 1 ----
# Hypothesis1: 0.8933333333333333
# Error1: 4.1066666666666665
#
# Hypothesis2: 1.5066666666666666
# Error2: 5.493333333333333
#
# Hypothesis3: 2.12
# Error3: 6.88
#
# w0 := w0 - alpha * 1/3.0 * ( 4.1066666666666665 * 1 + 5.493333333333333 * 1 + 6.88 * 1 +  ) = 0.49973333333333336
# w1 := w1 - alpha * 1/3.0 * ( 4.1066666666666665 * 1 + 5.493333333333333 * 2 + 6.88 * 3 +  ) = 1.0897777777777777
# Cost function = 31.458607407407403
#
#
#
# ---- iteration 2 ----
# Hypothesis1: 1.589511111111111
# Error1: 3.4104888888888887
#
# Hypothesis2: 2.679288888888889
# Error2: 4.320711111111111
#
# Hypothesis3: 3.7690666666666663
# Error3: 5.230933333333334
#
# w0 := w0 - alpha * 1/3.0 * ( 3.4104888888888887 * 1 + 4.320711111111111 * 1 + 5.230933333333334 * 1 +  ) = 0.6725617777777778
# w1 := w1 - alpha * 1/3.0 * ( 3.4104888888888887 * 1 + 4.320711111111111 * 2 + 5.230933333333334 * 3 +  ) = 1.4597072592592593
# Cost function = 19.220880834897116
#
#
#
# ---- iteration 3 ----
# Hypothesis1: 2.132269037037037
# Error1: 2.867730962962963
#
# Hypothesis2: 3.5919762962962962
# Error2: 3.4080237037037038
#
# Hypothesis3: 5.051683555555556
# Error3: 3.948316444444444
#
# w0 := w0 - alpha * 1/3.0 * ( 2.867730962962963 * 1 + 3.4080237037037038 * 1 + 3.948316444444444 * 1 +  ) = 0.8088827259259259
# w1 := w1 - alpha * 1/3.0 * ( 2.867730962962963 * 1 + 3.4080237037037038 * 2 + 3.948316444444444 * 3 +  ) = 1.7467569619753087
# Cost function = 11.80923639547107
#
#
#
# ---- iteration 4 ----
# Hypothesis1: 2.555639687901235
# Error1: 2.444360312098765
#
# Hypothesis2: 4.302396649876544
# Error2: 2.6976033501234564
#
# Hypothesis3: 6.049153611851852
# Error3: 2.9508463881481477
#
# w0 := w0 - alpha * 1/3.0 * ( 2.444360312098765 * 1 + 2.6976033501234564 * 1 + 2.9508463881481477 * 1 +  ) = 0.9167868599308642
# w1 := w1 - alpha * 1/3.0 * ( 2.444360312098765 * 1 + 2.6976033501234564 * 2 + 2.9508463881481477 * 3 +  ) = 1.9693183776658436
# Cost function = 7.3198185254692785
#
#
#
# ---- iteration 5 ----
# Hypothesis1: 2.886105237596708
# Error1: 2.113894762403292
#
# Hypothesis2: 4.855423615262551
# Error2: 2.144576384737449
#
# Hypothesis3: 6.824741992928395
# Error3: 2.175258007071605
#
# w0 := w0 - alpha * 1/3.0 * ( 2.113894762403292 * 1 + 2.144576384737449 * 1 + 2.175258007071605 * 1 +  ) = 1.002569915320362
# w1 := w1 - alpha * 1/3.0 * ( 2.113894762403292 * 1 + 2.144576384737449 * 2 + 2.175258007071605 * 3 +  ) = 2.141702665040417
# Cost function = 4.599835444606249
#
#
#
# ---- iteration 6 ----
# Hypothesis1: 3.144272580360779
# Error1: 1.855727419639221
#
# Hypothesis2: 5.285975245401196
# Error2: 1.714024754598804
#
# Hypothesis3: 7.427677910441613
# Error3: 1.5723220895583871
#
# w0 := w0 - alpha * 1/3.0 * ( 1.855727419639221 * 1 + 1.714024754598804 * 1 + 1.5723220895583871 * 1 +  ) = 1.0711309055043141
# w1 := w1 - alpha * 1/3.0 * ( 1.855727419639221 * 1 + 1.714024754598804 * 2 + 1.5723220895583871 * 3 +  ) = 2.2750459076739102
# Cost function = 2.9512672895638614
#
#
#
# ---- iteration 7 ----
# Hypothesis1: 3.346176813178224
# Error1: 1.6538231868217759
#
# Hypothesis2: 5.621222720852135
# Error2: 1.3787772791478652
#
# Hypothesis3: 7.8962686285260455
# Error3: 1.1037313714739545
#
# w0 := w0 - alpha * 1/3.0 * ( 1.6538231868217759 * 1 + 1.3787772791478652 * 1 + 1.1037313714739545 * 1 +  ) = 1.1262819966702287
# w1 := w1 - alpha * 1/3.0 * ( 1.6538231868217759 * 1 + 1.3787772791478652 * 2 + 1.1037313714739545 * 3 +  ) = 2.3780135324677687
# Cost function = 1.9514602863798336
#
#
#
# ---- iteration 8 ----
# Hypothesis1: 3.5042955291379974
# Error1: 1.4957044708620026
#
# Hypothesis2: 5.882309061605766
# Error2: 1.117690938394234
#
# Hypothesis3: 8.260322594073536
# Error3: 0.7396774059264644
#
# w0 := w0 - alpha * 1/3.0 * ( 1.4957044708620026 * 1 + 1.117690938394234 * 1 + 0.7396774059264644 * 1 +  ) = 1.170989634205998
# w1 := w1 - alpha * 1/3.0 * ( 1.4957044708620026 * 1 + 1.117690938394234 * 2 + 0.7396774059264644 * 3 +  ) = 2.4573484466735
# Cost function = 1.3444958542544232
#
#
#
# ---- iteration 9 ----
# Hypothesis1: 3.628338080879498
# Error1: 1.371661919120502
#
# Hypothesis2: 6.085686527552998
# Error2: 0.9143134724470023
#
# Hypothesis3: 8.543034974226499
# Error3: 0.45696502577350095
#
# w0 := w0 - alpha * 1/3.0 * ( 1.371661919120502 * 1 + 0.9143134724470023 * 1 + 0.45696502577350095 * 1 +  ) = 1.2075621731038781
# w1 := w1 - alpha * 1/3.0 * ( 1.371661919120502 * 1 + 0.9143134724470023 * 2 + 0.45696502577350095 * 3 +  ) = 2.5182975658913
# Cost function = 0.9754141936812033
#
#
#
# ---- iteration 10 ----
# Hypothesis1: 3.725859738995178
# Error1: 1.2741402610048218
#
# Hypothesis2: 6.244157304886478
# Error2: 0.7558426951135218
#
# Hypothesis3: 8.762454870777777
# Error3: 0.23754512922222304
#
# w0 := w0 - alpha * 1/3.0 * ( 1.2741402610048218 * 1 + 0.7558426951135218 * 1 + 0.23754512922222304 * 1 +  ) = 1.237795880908419
# w1 := w1 - alpha * 1/3.0 * ( 1.2741402610048218 * 1 + 0.7558426951135218 * 2 + 0.23754512922222304 * 3 +  ) = 2.5649437130766137
# Cost function = 0.7503864242957033
#
#
#
# ---- iteration 11 ----
# Hypothesis1: 3.8027395939850326
# Error1: 1.1972604060149674
#
# Hypothesis2: 6.367683307061647
# Error2: 0.6323166929383532
#
# Hypothesis3: 8.93262702013826
# Error3: 0.06737297986174084
#
# w0 := w0 - alpha * 1/3.0 * ( 1.1972604060149674 * 1 + 0.6323166929383532 * 1 + 0.06737297986174084 * 1 +  ) = 1.2630885486259533
# w1 := w1 - alpha * 1/3.0 * ( 1.1972604060149674 * 1 + 0.6323166929383532 * 2 + 0.06737297986174084 * 3 +  ) = 2.600463882829639
# Cost function = 0.6125986661316902
#
#
#
# ---- iteration 12 ----
# Hypothesis1: 3.8635524314555925
# Error1: 1.1364475685444075
#
# Hypothesis2: 6.464016314285232
# Error2: 0.5359836857147684
#
# Hypothesis3: 9.064480197114872
# Error3: -0.06448019711487163
#
# w0 := w0 - alpha * 1/3.0 * ( 1.1364475685444075 * 1 + 0.5359836857147684 * 1 + -0.06448019711487163 * 1 +  ) = 1.284527896054544
# w1 := w1 - alpha * 1/3.0 * ( 1.1364475685444075 * 1 + 0.5359836857147684 * 2 + -0.06448019711487163 * 3 +  ) = 2.62733020747803
# Cost function = 0.5276497610742854
#
#
#
# ---- iteration 13 ----
# Hypothesis1: 3.911858103532574
# Error1: 1.0881418964674259
#
# Hypothesis2: 6.539188311010604
# Error2: 0.46081168898939584
#
# Hypothesis3: 9.166518518488633
# Error3: -0.1665185184886333
#
# w0 := w0 - alpha * 1/3.0 * ( 1.0881418964674259 * 1 + 0.46081168898939584 * 1 + -0.1665185184886333 * 1 +  ) = 1.30296036361412
# w1 := w1 - alpha * 1/3.0 * ( 1.0881418964674259 * 1 + 0.46081168898939584 * 2 + -0.1665185184886333 * 3 +  ) = 2.6474663370644342
# Cost function = 0.4747095388522117
#
#
#
# ---- iteration 14 ----
# Hypothesis1: 3.9504267006785545
# Error1: 1.0495732993214455
#
# Hypothesis2: 6.597893037742988
# Error2: 0.4021069622570117
#
# Hypothesis3: 9.245359374807423
# Error3: -0.24535937480742298
#
# w0 := w0 - alpha * 1/3.0 * ( 1.0495732993214455 * 1 + 0.4021069622570117 * 1 + -0.24535937480742298 * 1 +  ) = 1.3190446421044004
# w1 := w1 - alpha * 1/3.0 * ( 1.0495732993214455 * 1 + 0.4021069622570117 * 2 + -0.24535937480742298 * 3 +  ) = 2.6623691250566104
# Cost function = 0.4411651141833186
#
#
#
# ---- iteration 15 ----
# Hypothesis1: 3.981413767161011
# Error1: 1.018586232838989
#
# Hypothesis2: 6.643782892217621
# Error2: 0.3562171077823786
#
# Hypothesis3: 9.306152017274231
# Error3: -0.3061520172742309
#
# w0 := w0 - alpha * 1/3.0 * ( 1.018586232838989 * 1 + 0.3562171077823786 * 1 + -0.3061520172742309 * 1 +  ) = 1.3332933264156956
# w1 := w1 - alpha * 1/3.0 * ( 1.018586232838989 * 1 + 0.3562171077823786 * 2 + -0.3061520172742309 * 3 +  ) = 2.6732033170110245
# Cost function = 0.4193791997623489
#
#
#
# ---- iteration 16 ----
# Hypothesis1: 4.00649664342672
# Error1: 0.9935033565732798
#
# Hypothesis2: 6.679699960437745
# Error2: 0.3203000395622553
#
# Hypothesis3: 9.35290327744877
# Error3: -0.35290327744876926
#
# w0 := w0 - alpha * 1/3.0 * ( 0.9935033565732798 * 1 + 0.3203000395622553 * 1 + -0.35290327744876926 * 1 +  ) = 1.3461053279981858
# w1 := w1 - alpha * 1/3.0 * ( 0.9935033565732798 * 1 + 0.3203000395622553 * 2 + -0.35290327744876926 * 3 +  ) = 2.6808752317223776
# Cost function = 0.404727252700013
#
#
#
# ---- iteration 17 ----
# Hypothesis1: 4.026980559720563
# Error1: 0.9730194402794368
#
# Hypothesis2: 6.707855791442941
# Error2: 0.29214420855705914
#
# Hypothesis3: 9.388731023165318
# Error3: -0.3887310231653185
#
# w0 := w0 - alpha * 1/3.0 * ( 0.9730194402794368 * 1 + 0.29214420855705914 * 1 + -0.3887310231653185 * 1 +  ) = 1.3577910963404682
# w1 := w1 - alpha * 1/3.0 * ( 0.9730194402794368 * 1 + 0.29214420855705914 * 2 + -0.3887310231653185 * 3 +  ) = 2.686090095561012
# Cost function = 0.3944089593754314
#
#
#
# ---- iteration 18 ----
# Hypothesis1: 4.04388119190148
# Error1: 0.9561188080985197
#
# Hypothesis2: 6.729971287462492
# Error2: 0.27002871253750804
#
# Hypothesis3: 9.416061383023505
# Error3: -0.41606138302350537
#
# w0 := w0 - alpha * 1/3.0 * ( 0.9561188080985197 * 1 + 0.27002871253750804 * 1 + -0.41606138302350537 * 1 +  ) = 1.3685922448419685
# w1 := w1 - alpha * 1/3.0 * ( 0.9561188080985197 * 1 + 0.27002871253750804 * 2 + -0.41606138302350537 * 3 +  ) = 2.6893966566823857
# Cost function = 0.38672858507927665
#
#
#
# ---- iteration 19 ----
# Hypothesis1: 4.057988901524354
# Error1: 0.9420110984756462
#
# Hypothesis2: 6.74738555820674
# Error2: 0.2526144417932601
#
# Hypothesis3: 9.436782214889126
# Error3: -0.43678221488912605
#
# w0 := w0 - alpha * 1/3.0 * ( 0.9420110984756462 * 1 + 0.2526144417932601 * 1 + -0.43678221488912605 * 1 +  ) = 1.3786968225136988
# w1 := w1 - alpha * 1/3.0 * ( 0.9420110984756462 * 1 + 0.2526144417932601 * 2 + -0.43678221488912605 * 3 +  ) = 2.691221901180983
# Cost function = 0.38065922303242156
#
#
#
# ---- iteration 20 ----
# Hypothesis1: 4.069918723694681
# Error1: 0.9300812763053186
#
# Hypothesis2: 6.761140624875664
# Error2: 0.23885937512433575
#
# Hypothesis3: 9.452362526056648
# Error3: -0.45236252605664795
#
# w0 := w0 - alpha * 1/3.0 * ( 0.9300812763053186 * 1 + 0.23885937512433575 * 1 + -0.45236252605664795 * 1 +  ) = 1.3882511975186722
# w1 := w1 - alpha * 1/3.0 * ( 0.9300812763053186 * 1 + 0.23885937512433575 * 2 + -0.45236252605664795 * 3 +  ) = 2.691898067159437
# Cost function = 0.3755789455329566
#
#
#
# ---- iteration 21 ----
# Hypothesis1: 4.080149264678109
# Error1: 0.9198507353218908
#
# Hypothesis2: 6.772047331837546
# Error2: 0.2279526681624544
#
# Hypothesis3: 9.463945398996982
# Error3: -0.46394539899698195
#
# w0 := w0 - alpha * 1/3.0 * ( 0.9198507353218908 * 1 + 0.2279526681624544 * 1 + -0.46394539899698195 * 1 +  ) = 1.3973693042451705
# w1 := w1 - alpha * 1/3.0 * ( 0.9198507353218908 * 1 + 0.2279526681624544 * 2 + -0.46394539899698195 * 3 +  ) = 2.6916836654881817
# Cost function = 0.3711110424816913
#
#
#
# ---- iteration 22 ----
# Hypothesis1: 4.089052969733352
# Error1: 0.910947030266648
#
# Hypothesis2: 6.780736635221534
# Error2: 0.21926336477846586
#
# Hypothesis3: 9.472420300709716
# Error3: -0.4724203007097163
#
# w0 := w0 - alpha * 1/3.0 * ( 0.910947030266648 * 1 + 0.21926336477846586 * 1 + -0.4724203007097163 * 1 +  ) = 1.406139838836309
# w1 := w1 - alpha * 1/3.0 * ( 0.910947030266648 * 1 + 0.21926336477846586 * 2 + -0.4724203007097163 * 3 +  ) = 2.6907798369241074
# Cost function = 0.36702728520275285
#
#
#
# ---- iteration 23 ----
# Hypothesis1: 4.096919675760416
# Error1: 0.9030803242395837
#
# Hypothesis2: 6.787699512684524
# Error2: 0.2123004873154759
#
# Hypothesis3: 9.47847934960863
# Error3: -0.47847934960863014
#
# w0 := w0 - alpha * 1/3.0 * ( 0.9030803242395837 * 1 + 0.2123004873154759 * 1 + -0.47847934960863014 * 1 +  ) = 1.4146318583289281
# w1 := w1 - alpha * 1/3.0 * ( 0.9030803242395837 * 1 + 0.2123004873154759 * 2 + -0.47847934960863014 * 3 +  ) = 2.689343080258036
# Cost function = 0.36318935231498595
#
#
#
# ---- iteration 24 ----
# Hypothesis1: 4.103974938586964
# Error1: 0.8960250614130363
#
# Hypothesis2: 6.7933180188449995
# Error2: 0.20668198115500047
#
# Hypothesis3: 9.482661099103035
# Error3: -0.48266109910303534
#
# w0 := w0 - alpha * 1/3.0 * ( 0.8960250614130363 * 1 + 0.20668198115500047 * 1 + -0.48266109910303534 * 1 +  ) = 1.422899137575128
# w1 := w1 - alpha * 1/3.0 * ( 0.8960250614130363 * 1 + 0.20668198115500047 * 2 + -0.48266109910303534 * 3 +  ) = 2.6874951566102214
# Cost function = 0.35951336286724717
#
#
#
# ---- iteration 25 ----
# Hypothesis1: 4.110394294185349
# Error1: 0.8896057058146507
#
# Hypothesis2: 6.797889450795571
# Error2: 0.20211054920442884
#
# Hypothesis3: 9.485384607405791
# Error3: -0.48538460740579126
#
# w0 := w0 - alpha * 1/3.0 * ( 0.8896057058146507 * 1 + 0.20211054920442884 * 1 + -0.48538460740579126 * 1 +  ) = 1.4309835595433054
# w1 := w1 - alpha * 1/3.0 * ( 0.8896057058146507 * 1 + 0.20211054920442884 * 2 + -0.48538460740579126 * 3 +  ) = 2.685330796370303
# Cost function = 0.3559484010080576
#
#
#
# ---- iteration 26 ----
# Hypothesis1: 4.116314355913609
# Error1: 0.8836856440863912
#
# Hypothesis2: 6.801645152283911
# Error2: 0.19835484771608858
#
# Hypothesis3: 9.486975948654214
# Error3: -0.486975948654214
#
# w0 := w0 - alpha * 1/3.0 * ( 0.8836856440863912 * 1 + 0.19835484771608858 * 1 + -0.486975948654214 * 1 +  ) = 1.4389177534519488
# w1 := w1 - alpha * 1/3.0 * ( 0.8836856440863912 * 1 + 0.19835484771608858 * 2 + -0.486975948654214 * 3 +  ) = 2.682923696284382
# Cost function = 0.3524635125815081
#
#
#
# ---- iteration 27 ----
# Hypothesis1: 4.121841449736331
# Error1: 0.8781585502636693
#
# Hypothesis2: 6.804765146020713
# Error2: 0.19523485397928741
#
# Hypothesis3: 9.487688842305094
# Error3: -0.4876888423050936
#
# w0 := w0 - alpha * 1/3.0 * ( 0.8781585502636693 * 1 + 0.19523485397928741 * 1 + -0.4876888423050936 * 1 +  ) = 1.4467271476111203
# w1 := w1 - alpha * 1/3.0 * ( 0.8781585502636693 * 1 + 0.19523485397928741 * 2 + -0.4876888423050936 * 3 +  ) = 2.6803311860351413
# Cost function = 0.3490398315061285
#
#
#
# ---- iteration 28 ----
# Hypothesis1: 4.127058333646262
# Error1: 0.8729416663537384
#
# Hypothesis2: 6.8073895196814025
# Error2: 0.1926104803185975
#
# Hypothesis3: 9.487720705716544
# Error3: -0.48772070571654424
#
# w0 := w0 - alpha * 1/3.0 * ( 0.8729416663537384 * 1 + 0.1926104803185975 * 1 + -0.48772070571654424 * 1 +  ) = 1.454431566823864
# w1 := w1 - alpha * 1/3.0 * ( 0.8729416663537384 * 1 + 0.1926104803185975 * 2 + -0.48772070571654424 * 3 +  ) = 2.677597859499692
# Cost function = 0.3456658122565487
#
#
#
# ---- iteration 29 ----
# Hypothesis1: 4.132029426323556
# Error1: 0.8679705736764438
#
# Hypothesis2: 6.809627285823248
# Error2: 0.1903727141767524
#
# Hypothesis3: 9.48722514532294
# Error3: -0.4872251453229399
#
# w0 := w0 - alpha * 1/3.0 * ( 0.8679705736764438 * 1 + 0.1903727141767524 * 1 + -0.4872251453229399 * 1 +  ) = 1.4620464753909341
# w1 := w1 - alpha * 1/3.0 * ( 0.8679705736764438 * 1 + 0.1903727141767524 * 2 + -0.4872251453229399 * 3 +  ) = 2.6747584003805067
# Cost function = 0.34233434310206606
#
#
#
# ---- iteration 30 ----
# Hypothesis1: 4.136804875771441
# Error1: 0.8631951242285592
#
# Hypothesis2: 6.811563276151947
# Error2: 0.18843672384805288
#
# Hypothesis3: 9.486321676532455
# Error3: -0.48632167653245517
#
# w0 := w0 - alpha * 1/3.0 * ( 0.8631951242285592 * 1 + 0.18843672384805288 * 1 + -0.48632167653245517 * 1 +  ) = 1.4695839443448562
# w1 := w1 - alpha * 1/3.0 * ( 0.8631951242285592 * 1 + 0.18843672384805288 * 2 + -0.48632167653245517 * 3 +  ) = 2.671839780944871
# Cost function = 0.3390409981506276
#
#
#
# ---- iteration 31 ----
# Hypothesis1: 4.141423725289727
# Error1: 0.8585762747102734
#
# Hypothesis2: 6.813263506234598
# Error2: 0.1867364937654017
#
# Hypothesis3: 9.485103287179468
# Error3: -0.48510328717946827
#
# w0 := w0 - alpha * 1/3.0 * ( 0.8585762747102734 * 1 + 0.1867364937654017 * 1 + -0.48510328717946827 * 1 +  ) = 1.4770534040954724
# w1 := w1 - alpha * 1/3.0 * ( 0.8585762747102734 * 1 + 0.1867364937654017 * 2 + -0.48510328717946827 * 3 +  ) = 2.6688629729542397
# Cost function = 0.3357829789438308
#
#
#
# ---- iteration 32 ----
# Hypothesis1: 4.145916377049712
# Error1: 0.854083622950288
#
# Hypothesis2: 6.814779350003952
# Error2: 0.18522064999604826
#
# Hypothesis3: 9.48364232295819
# Error3: -0.48364232295818965
#
# w0 := w0 - alpha * 1/3.0 * ( 0.854083622950288 * 1 + 0.18522064999604826 * 1 + -0.48364232295818965 * 1 +  ) = 1.4844622300953143
# w1 := w1 - alpha * 1/3.0 * ( 0.854083622950288 * 1 + 0.18522064999604826 * 2 + -0.48364232295818965 * 3 +  ) = 2.665844279008477
# Cost function = 0.33255847357774737
#
#
#
# ---- iteration 33 ----
# Hypothesis1: 4.150306509103792
# Error1: 0.8496934908962084
#
# Hypothesis2: 6.816150788112268
# Error2: 0.18384921188773173
#
# Hypothesis3: 9.481995067120746
# Error3: -0.4819950671207458
#
# w0 := w0 - alpha * 1/3.0 * ( 0.8496934908962084 * 1 + 0.18384921188773173 * 1 + -0.4819950671207458 * 1 +  ) = 1.4918161985708236
# w1 := w1 - alpha * 1/3.0 * ( 0.8496934908962084 * 1 + 0.18384921188773173 * 2 + -0.4819950671207458 * 3 +  ) = 2.6627963685192695
# Cost function = 0.32936626863728574
#
#
#
# ---- iteration 34 ----
# Hypothesis1: 4.154612567090093
# Error1: 0.8453874329099067
#
# Hypothesis2: 6.817408935609363
# Error2: 0.18259106439063721
#
# Hypothesis3: 9.480205304128631
# Error3: -0.4802053041286314
#
# w0 := w0 - alpha * 1/3.0 * ( 0.8453874329099067 * 1 + 0.18259106439063721 * 1 + -0.4802053041286314 * 1 +  ) = 1.499119841146449
# w1 := w1 - alpha * 1/3.0 * ( 0.8453874329099067 * 1 + 0.18259106439063721 * 2 + -0.4802053041286314 * 3 +  ) = 2.65972908384334
# Cost function = 0.326205514210193
#
#
#
# ---- iteration 35 ----
# Hypothesis1: 4.158848924989789
# Error1: 0.8411510750102114
#
# Hypothesis2: 6.8185780088331285
# Error2: 0.18142199116687152
#
# Hypothesis3: 9.478307092676468
# Error3: -0.4783070926764683
#
# w0 := w0 - alpha * 1/3.0 * ( 0.8411510750102114 * 1 + 0.18142199116687152 * 1 + -0.4783070926764683 * 1 +  ) = 1.5063767207931238
# w1 := w1 - alpha * 1/3.0 * ( 0.8411510750102114 * 1 + 0.18142199116687152 * 2 + -0.4783070926764683 * 3 +  ) = 2.6566500675675337
# Cost function = 0.32307558159146743
#
#
#
# ---- iteration 36 ----
# Hypothesis1: 4.163026788360657
# Error1: 0.8369732116393429
#
# Hypothesis2: 6.819676855928192
# Error2: 0.18032314407180827
#
# Hypothesis3: 9.476326923495725
# Error3: -0.4763269234957246
#
# w0 := w0 - alpha * 1/3.0 * ( 0.8369732116393429 * 1 + 0.18032314407180827 * 1 + -0.4763269234957246 * 1 +  ) = 1.5135896465559961
# w1 := w1 - alpha * 1/3.0 * ( 0.8369732116393429 * 1 + 0.18032314407180827 * 2 + -0.4763269234957246 * 3 +  ) = 2.653565250624811
# Cost function = 0.3199759771122401
#
#
#
# ---- iteration 37 ----
# Hypothesis1: 4.167154897180807
# Error1: 0.832845102819193
#
# Hypothesis2: 6.820720147805618
# Error2: 0.17927985219438192
#
# Hypothesis3: 9.47428539843043
# Error3: -0.47428539843043005
#
# w0 := w0 - alpha * 1/3.0 * ( 0.832845102819193 * 1 + 0.17927985219438192 * 1 + -0.47428539843043005 * 1 +  ) = 1.5207608406437714
# w1 := w1 - alpha * 1/3.0 * ( 0.832845102819193 * 1 + 0.17927985219438192 * 2 + -0.47428539843043005 * 3 +  ) = 2.6504792321170334
# Cost function = 0.3169062899523545
#
#
#
# ---- iteration 38 ----
# Hypothesis1: 4.1712400727608046
# Error1: 0.8287599272391954
#
# Hypothesis2: 6.821719304877838
# Error2: 0.1782806951221616
#
# Hypothesis3: 9.47219853699487
# Error3: -0.47219853699487047
#
# w0 := w0 - alpha * 1/3.0 * ( 0.8287599272391954 * 1 + 0.1782806951221616 * 1 + -0.47219853699487047 * 1 +  ) = 1.5278920684486579
# w1 := w1 - alpha * 1/3.0 * ( 0.8287599272391954 * 1 + 0.1782806951221616 * 2 + -0.47219853699487047 * 3 +  ) = 2.647395574870352
# Cost function = 0.31386616053028454
#
#
#
# ---- iteration 39 ----
# Hypothesis1: 4.17528764331901
# Error1: 0.8247123566809904
#
# Hypothesis2: 6.822683218189362
# Error2: 0.1773167818106378
#
# Hypothesis3: 9.470078793059715
# Error3: -0.4700787930597148
#
# w0 := w0 - alpha * 1/3.0 * ( 0.8247123566809904 * 1 + 0.1773167818106378 * 1 + -0.4700787930597148 * 1 +  ) = 1.5349847397210834
# w1 := w1 - alpha * 1/3.0 * ( 0.8247123566809904 * 1 + 0.1773167818106378 * 2 + -0.4700787930597148 * 3 +  ) = 2.6443170354186605
# Cost function = 0.31085526135282415
#
#
#
# ---- iteration 40 ----
# Hypothesis1: 4.179301775139744
# Error1: 0.8206982248602559
#
# Hypothesis2: 6.823618810558404
# Error2: 0.17638118944159586
#
# Hypothesis3: 9.467935845977065
# Error3: -0.46793584597706506
#
# w0 := w0 - alpha * 1/3.0 * ( 0.8206982248602559 * 1 + 0.17638118944159586 * 1 + -0.46793584597706506 * 1 +  ) = 1.5420399872987471
# w1 := w1 - alpha * 1/3.0 * ( 0.8206982248602559 * 1 + 0.17638118944159586 * 2 + -0.46793584597706506 * 3 +  ) = 2.6412457429628238
# Cost function = 0.30787328540929293
#
#
#
# ---- iteration 41 ----
# Hypothesis1: 4.183285730261571
# Error1: 0.8167142697384291
#
# Hypothesis2: 6.824531473224395
# Error2: 0.17546852677560487
#
# Hypothesis3: 9.465777216187218
# Error3: -0.46577721618721846
#
# w0 := w0 - alpha * 1/3.0 * ( 0.8167142697384291 * 1 + 0.17546852677560487 * 1 + -0.46577721618721846 * 1 +  ) = 1.5490587283697714
# w1 := w1 - alpha * 1/3.0 * ( 0.8167142697384291 * 1 + 0.17546852677560487 * 2 + -0.46577721618721846 * 3 +  ) = 2.6381833386258635
# Cost function = 0.30491993913409715
#
#
#
# ---- iteration 42 ----
# Hypothesis1: 4.187242066995635
# Error1: 0.8127579330043648
#
# Hypothesis2: 6.825425405621498
# Error2: 0.17457459437850176
#
# Hypothesis3: 9.463608744247363
# Error3: -0.4636087442473631
#
# w0 := w0 - alpha * 1/3.0 * ( 0.8127579330043648 * 1 + 0.17457459437850176 * 1 + -0.4636087442473631 * 1 +  ) = 1.5560417121449115
# w1 := w1 - alpha * 1/3.0 * ( 0.8127579330043648 * 1 + 0.17457459437850176 * 2 + -0.4636087442473631 * 3 +  ) = 2.6351310838127873
# Cost function = 0.3019949381355209
#
#
#
# ---- iteration 43 ----
# Hypothesis1: 4.191172795957699
# Error1: 0.8088272040423012
#
# Hypothesis2: 6.826303879770486
# Error2: 0.17369612022951397
#
# Hypothesis3: 9.461434963583272
# Error3: -0.4614349635832724
#
# w0 := w0 - alpha * 1/3.0 * ( 0.8088272040423012 * 1 + 0.17369612022951397 * 1 + -0.4614349635832724 * 1 +  ) = 1.5629895569540921
# w1 := w1 - alpha * 1/3.0 * ( 0.8088272040423012 * 1 + 0.17369612022951397 * 2 + -0.4614349635832724 * 3 +  ) = 2.6320899445294743
# Cost function = 0.29909800459958935
#
#
#
# ---- iteration 44 ----
# Hypothesis1: 4.1950795014835665
# Error1: 0.8049204985164335
#
# Hypothesis2: 6.827169446013041
# Error2: 0.1728305539869588
#
# Hypothesis3: 9.459259390542515
# Error3: -0.4592593905425151
#
# w0 := w0 - alpha * 1/3.0 * ( 0.8049204985164335 * 1 + 0.1728305539869588 * 1 + -0.4592593905425151 * 1 +  ) = 1.5699027791135705
# w1 := w1 - alpha * 1/3.0 * ( 0.8049204985164335 * 1 + 0.1728305539869588 * 2 + -0.4592593905425151 * 3 +  ) = 2.629060656994312
# Cost function = 0.29622886570828844
#
#
#
# ---- iteration 45 ----
# Hypothesis1: 4.198963436107882
# Error1: 0.8010365638921177
#
# Hypothesis2: 6.828024093102194
# Error2: 0.1719759068978064
#
# Hypothesis3: 9.457084750096506
# Error3: -0.45708475009650584
#
# w0 := w0 - alpha * 1/3.0 * ( 0.8010365638921177 * 1 + 0.1719759068978064 * 1 + -0.45708475009650584 * 1 +  ) = 1.5767818153894828
# w1 := w1 - alpha * 1/3.0 * ( 0.8010365638921177 * 1 + 0.1719759068978064 * 2 + -0.45708475009650584 * 3 +  ) = 2.6260437786929547
# Cost function = 0.29338725267206633
#
#
#
# ---- iteration 46 ----
# Hypothesis1: 4.202825594082437
# Error1: 0.7971744059175627
#
# Hypothesis2: 6.828869372775392
# Error2: 0.17113062722460803
#
# Hypothesis3: 9.454913151468347
# Error3: -0.45491315146834665
#
# w0 := w0 - alpha * 1/3.0 * ( 0.7971744059175627 * 1 + 0.17113062722460803 * 1 + -0.45491315146834665 * 1 +  ) = 1.5836270404784671
# w1 := w1 - alpha * 1/3.0 * ( 0.7971744059175627 * 1 + 0.17113062722460803 * 2 + -0.45491315146834665 * 3 +  ) = 2.623039728105778
# Cost function = 0.2905729001343899
#
#
#
# ---- iteration 47 ----
# Hypothesis1: 4.206666768584245
# Error1: 0.7933332314157546
#
# Hypothesis2: 6.829706496690022
# Error2: 0.17029350330997772
#
# Hypothesis3: 9.452746224795801
# Error3: -0.45274622479580096
#
# w0 := w0 - alpha * 1/3.0 * ( 0.7933332314157546 * 1 + 0.17029350330997772 * 1 + -0.45274622479580096 * 1 +  ) = 1.5904387806108662
# w1 := w1 - alpha * 1/3.0 * ( 0.7933332314157546 * 1 + 0.17029350330997772 * 2 + -0.45274622479580096 * 3 +  ) = 2.6200488156210886
# Cost function = 0.28778554580166615
#
#
#
# ---- iteration 48 ----
# Hypothesis1: 4.210487596231955
# Error1: 0.789512403768045
#
# Hypothesis2: 6.830536411853044
# Error2: 0.1694635881469564
#
# Hypothesis3: 9.450585227474132
# Error3: -0.4505852274741322
#
# w0 := w0 - alpha * 1/3.0 * ( 0.789512403768045 * 1 + 0.1694635881469564 * 1 + -0.4505852274741322 * 1 +  ) = 1.5972173241367444
# w1 := w1 - alpha * 1/3.0 * ( 0.789512403768045 * 1 + 0.1694635881469564 * 2 + -0.4505852274741322 * 3 +  ) = 2.617071267589616
# Cost function = 0.2850249302097177
#
#
#
# ---- iteration 49 ----
# Hypothesis1: 4.21428859172636
# Error1: 0.7857114082736398
#
# Hypothesis2: 6.831359859315977
# Error2: 0.16864014068402344
#
# Hypothesis3: 9.448431126905593
# Error3: -0.44843112690559295
#
# w0 := w0 - alpha * 1/3.0 * ( 0.7857114082736398 * 1 + 0.16864014068402344 * 1 + -0.44843112690559295 * 1 +  ) = 1.6039629297641054
# w1 := w1 - alpha * 1/3.0 * ( 0.7857114082736398 * 1 + 0.16864014068402344 * 2 + -0.44843112690559295 * 3 +  ) = 2.6141072450419482
# Cost function = 0.28229079657303113
#
#
#
# ---- iteration 50 ----
# Hypothesis1: 4.218070174806053
# Error1: 0.7819298251939468
#
# Hypothesis2: 6.832177419848001
# Error2: 0.16782258015199858
#
# Hypothesis3: 9.44628466488995
# Error3: -0.44628466488994967
#
# w0 := w0 - alpha * 1/3.0 * ( 0.7819298251939468 * 1 + 0.16782258015199858 * 1 + -0.44628466488994967 * 1 +  ) = 1.6106758329701854
# w1 := w1 - alpha * 1/3.0 * ( 0.7819298251939468 * 1 + 0.16782258015199858 * 2 + -0.44628466488994967 * 3 +  ) = 2.6111568582529894
# Cost function = 0.27958289068421494
#
#
#
# ---- iteration 51 ----
# Hypothesis1: 4.221832691223175
# Error1: 0.7781673087768253
#
# Hypothesis2: 6.832989549476164
# Error2: 0.16701045052383634
#
# Hypothesis3: 9.444146407729153
# Error3: -0.4441464077291535
#
# w0 := w0 - alpha * 1/3.0 * ( 0.7781673087768253 * 1 + 0.16701045052383634 * 1 + -0.4441464077291535 * 1 +  ) = 1.6173562509911388
# w1 := w1 - alpha * 1/3.0 * ( 0.7781673087768253 * 1 + 0.16701045052383634 * 2 + -0.4441464077291535 * 3 +  ) = 2.6082201780748164
# Cost function = 0.27690096084395105
#
#
#
# ---- iteration 52 ----
# Hypothesis1: 4.225576429065955
# Error1: 0.7744235709340446
#
# Hypothesis2: 6.833796607140772
# Error2: 0.16620339285922814
#
# Hypothesis3: 9.442016785215587
# Error3: -0.4420167852155874
#
# w0 := w0 - alpha * 1/3.0 * ( 0.7744235709340446 * 1 + 0.16620339285922814 * 1 + -0.4420167852155874 * 1 +  ) = 1.6240043867055078
# w1 := w1 - alpha * 1/3.0 * ( 0.7744235709340446 * 1 + 0.16620339285922814 * 2 + -0.4420167852155874 * 3 +  ) = 2.605297244754893
# Cost function = 0.2742447578094929
#
#
#
# ---- iteration 53 ----
# Hypothesis1: 4.229301631460401
# Error1: 0.7706983685395992
#
# Hypothesis2: 6.834598876215294
# Error2: 0.16540112378470617
#
# Hypothesis3: 9.439896120970186
# Error3: -0.43989612097018593
#
# w0 := w0 - alpha * 1/3.0 * ( 0.7706983685395992 * 1 + 0.16540112378470617 * 1 + -0.43989612097018593 * 1 +  ) = 1.6306204316568962
# w1 := w1 - alpha * 1/3.0 * ( 0.7706983685395992 * 1 + 0.16540112378470617 * 2 + -0.43989612097018593 * 3 +  ) = 2.602388074797539
# Cost function = 0.27161403475448664
#
#
#
# ---- iteration 54 ----
# Hypothesis1: 4.233008506454436
# Error1: 0.7669914935455644
#
# Hypothesis2: 6.835396581251975
# Error2: 0.1646034187480252
#
# Hypothesis3: 9.437784656049514
# Error3: -0.437784656049514
#
# w0 := w0 - alpha * 1/3.0 * ( 0.7669914935455644 * 1 + 0.1646034187480252 * 1 + -0.437784656049514 * 1 +  ) = 1.6372045684068173
# w1 := w1 - alpha * 1/3.0 * ( 0.7669914935455644 * 1 + 0.1646034187480252 * 2 + -0.437784656049514 * 3 +  ) = 2.59949266630278
# Cost function = 0.2690085472357282
#
#
#
# ---- iteration 55 ----
# Hypothesis1: 4.236697234709597
# Error1: 0.763302765290403
#
# Hypothesis2: 6.836189901012378
# Error2: 0.16381009898762233
#
# Hypothesis3: 9.435682567315158
# Error3: -0.4356825673151583
#
# w0 := w0 - alpha * 1/3.0 * ( 0.763302765290403 * 1 + 0.16381009898762233 * 1 + -0.4356825673151583 * 1 +  ) = 1.6437569723663221
# w1 := w1 - alpha * 1/3.0 * ( 0.763302765290403 * 1 + 0.16381009898762233 * 2 + -0.4356825673151583 * 3 +  ) = 2.5966110031203824
# Cost function = 0.2664280531642127
#
#
#
# ---- iteration 56 ----
# Hypothesis1: 4.240367975486705
# Error1: 0.7596320245132953
#
# Hypothesis2: 6.836978978607087
# Error2: 0.16302102139291286
#
# Hypothesis3: 9.433589981727469
# Error3: -0.43358998172746865
#
# w0 := w0 - alpha * 1/3.0 * ( 0.7596320245132953 * 1 + 0.16302102139291286 * 1 + -0.43358998172746865 * 1 +  ) = 1.6502778132220386
# w1 := w1 - alpha * 1/3.0 * ( 0.7596320245132953 * 1 + 0.16302102139291286 * 2 + -0.43358998172746865 * 3 +  ) = 2.5937430580819387
# Cost function = 0.2638723127788609
#
#
#
# ---- iteration 57 ----
# Hypothesis1: 4.244020871303977
# Error1: 0.7559791286960227
#
# Hypothesis2: 6.8377639293859165
# Error2: 0.16223607061408352
#
# Hypothesis3: 9.431506987467854
# Error3: -0.4315069874678539
#
# w0 := w0 - alpha * 1/3.0 * ( 0.7559791286960227 * 1 + 0.16223607061408352 * 1 + -0.4315069874678539 * 1 +  ) = 1.656767256046602
# w1 := w1 - alpha * 1/3.0 * ( 0.7559791286960227 * 1 + 0.16223607061408352 * 2 + -0.4315069874678539 * 3 +  ) = 2.5908887955155473
# Cost function = 0.26134108862195937
#
#
#
# ---- iteration 58 ----
# Hypothesis1: 4.247656051562149
# Error1: 0.7523439484378507
#
# Hypothesis2: 6.838544847077697
# Error2: 0.1614551529223034
#
# Hypothesis3: 9.429433642593244
# Error3: -0.4294336425932439
#
# w0 := w0 - alpha * 1/3.0 * ( 0.7523439484378507 * 1 + 0.1614551529223034 * 1 + -0.4294336425932439 * 1 +  ) = 1.663225462163494
# w1 := w1 - alpha * 1/3.0 * ( 0.7523439484378507 * 1 + 0.1614551529223034 * 2 + -0.4294336425932439 * 3 +  ) = 2.5880481732022504
# Cost function = 0.2588341455157072
#
#
#
# ---- iteration 59 ----
# Hypothesis1: 4.251273635365744
# Error1: 0.7487263646342557
#
# Hypothesis2: 6.839321808567995
# Error2: 0.16067819143200524
#
# Hypothesis3: 9.427369981770246
# Error3: -0.4273699817702461
#
# w0 := w0 - alpha * 1/3.0 * ( 0.7487263646342557 * 1 + 0.16067819143200524 * 1 + -0.4273699817702461 * 1 +  ) = 1.6696525898207744
# w1 := w1 - alpha * 1/3.0 * ( 0.7487263646342557 * 1 + 0.16067819143200524 * 2 + -0.4273699817702461 * 3 +  ) = 2.5852211438980843
# Cost function = 0.2563512505395297
#
#
#
# ---- iteration 60 ----
# Hypothesis1: 4.254873733718859
# Error1: 0.7451262662811411
#
# Hypothesis2: 6.840094877616943
# Error2: 0.15990512238305676
#
# Hypothesis3: 9.425316021515027
# Error3: -0.4253160215150267
#
# w0 := w0 - alpha * 1/3.0 * ( 0.7451262662811411 * 1 + 0.15990512238305676 * 1 + -0.4253160215150267 * 1 +  ) = 1.6760487947160967
# w1 := w1 - alpha * 1/3.0 * ( 0.7451262662811411 * 1 + 0.15990512238305676 * 2 + -0.4253160215150267 * 3 +  ) = 2.582407656518113
# Cost function = 0.2538921730079283
#
#
#
# ---- iteration 61 ----
# Hypothesis1: 4.25845645123421
# Error1: 0.7415435487657902
#
# Hypothesis2: 6.8408641077523225
# Error2: 0.15913589224767755
#
# Hypothesis3: 9.423271764270437
# Error3: -0.4232717642704369
#
# w0 := w0 - alpha * 1/3.0 * ( 0.7415435487657902 * 1 + 0.15913589224767755 * 1 + -0.4232717642704369 * 1 +  ) = 1.6824142304060037
# w1 := w1 - alpha * 1/3.0 * ( 0.7415435487657902 * 1 + 0.15913589224767755 * 2 + -0.4232717642704369 * 3 +  ) = 2.579607657057444
# Cost function = 0.2514566844487448
#
#
#
# ---- iteration 62 ----
# Hypothesis1: 4.2620218874634475
# Error1: 0.7379781125365525
#
# Hypothesis2: 6.841629544520892
# Error2: 0.15837045547910833
#
# Hypothesis3: 9.421237201578336
# Error3: -0.4212372015783359
#
# w0 := w0 - alpha * 1/3.0 * ( 0.7379781125365525 * 1 + 0.15837045547910833 * 1 + -0.4212372015783359 * 1 +  ) = 1.688749048625168
# w1 := w1 - alpha * 1/3.0 * ( 0.7379781125365525 * 1 + 0.15837045547910833 * 2 + -0.4212372015783359 * 3 +  ) = 2.5768210893075745
# Cost function = 0.24904455858174013
#
#
#
# ---- iteration 63 ----
# Hypothesis1: 4.265570137932743
# Error1: 0.7344298620672571
#
# Hypothesis2: 6.8423912272403165
# Error2: 0.15760877275968355
#
# Hypothesis3: 9.419212316547892
# Error3: -0.4192123165478918
#
# w0 := w0 - alpha * 1/3.0 * ( 0.7344298620672571 * 1 + 0.15760877275968355 * 1 + -0.4192123165478918 * 1 +  ) = 1.6950533995355552
# w1 := w1 - alpha * 1/3.0 * ( 0.7344298620672571 * 1 + 0.15760877275968355 * 2 + -0.4192123165478918 * 3 +  ) = 2.5740478954134804
# Cost function = 0.24665557129746457
#
#
#
# ---- iteration 64 ----
# Hypothesis1: 4.269101294949036
# Error1: 0.7308987050509641
#
# Hypothesis2: 6.843149190362516
# Error2: 0.15685080963748366
#
# Hypothesis3: 9.417197085775996
# Error3: -0.4171970857759959
#
# w0 := w0 - alpha * 1/3.0 * ( 0.7308987050509641 * 1 + 0.15685080963748366 * 1 + -0.4171970857759959 * 1 +  ) = 1.7013274319210545
# w1 := w1 - alpha * 1/3.0 * ( 0.7308987050509641 * 1 + 0.15685080963748366 * 2 + -0.4171970857759959 * 3 +  ) = 2.571288016306786
# Cost function = 0.2442895006363647
#
#
#
# ---- iteration 65 ----
# Hypothesis1: 4.272615448227841
# Error1: 0.7273845517721593
#
# Hypothesis2: 6.843903464534627
# Error2: 0.15609653546537317
#
# Hypothesis3: 9.415191480841413
# Error3: -0.415191480841413
#
# w0 := w0 - alpha * 1/3.0 * ( 0.7273845517721593 * 1 + 0.15609653546537317 * 1 + -0.415191480841413 * 1 +  ) = 1.7075712933396694
# w1 := w1 - alpha * 1/3.0 * ( 0.7273845517721593 * 1 + 0.15609653546537317 * 2 + -0.415191480841413 * 3 +  ) = 2.5685413920425018
# Cost function = 0.24194612676812102
#
#
#
# ---- iteration 66 ----
# Hypothesis1: 4.276112685382171
# Error1: 0.7238873146178291
#
# Hypothesis2: 6.844654077424673
# Error2: 0.15534592257532687
#
# Hypothesis3: 9.413195469467174
# Error3: -0.41319546946717445
#
# w0 := w0 - alpha * 1/3.0 * ( 0.7238873146178291 * 1 + 0.15534592257532687 * 1 + -0.41319546946717445 * 1 +  ) = 1.7137851302426825
# w1 := w1 - alpha * 1/3.0 * ( 0.7238873146178291 * 1 + 0.15534592257532687 * 2 + -0.41319546946717445 * 3 +  ) = 2.565807962060728
# Cost function = 0.23962523197119662
#
#
#
# ---- iteration 67 ----
# Hypothesis1: 4.2795930923034105
# Error1: 0.7204069076965895
#
# Hypothesis2: 6.845401054364139
# Error2: 0.15459894563586118
#
# Hypothesis3: 9.411209016424866
# Error3: -0.4112090164248663
#
# w0 := w0 - alpha * 1/3.0 * ( 0.7204069076965895 * 1 + 0.15459894563586118 * 1 + -0.4112090164248663 * 1 +  ) = 1.7199690880681169
# w1 := w1 - alpha * 1/3.0 * ( 0.7204069076965895 * 1 + 0.15459894563586118 * 2 + -0.4112090164248663 * 3 +  ) = 2.5630876653899772
# Cost function = 0.23732660061259614
#
#
#
# ---- iteration 68 ----
# Hypothesis1: 4.283056753458094
# Error1: 0.7169432465419057
#
# Hypothesis2: 6.846144418848072
# Error2: 0.15385558115192843
#
# Hypothesis3: 9.409232084238049
# Error3: -0.4092320842380488
#
# w0 := w0 - alpha * 1/3.0 * ( 0.7169432465419057 * 1 + 0.15385558115192843 * 1 + -0.4092320842380488 * 1 +  ) = 1.726123311314194
# w1 := w1 - alpha * 1/3.0 * ( 0.7169432465419057 * 1 + 0.15385558115192843 * 2 + -0.4092320842380488 * 3 +  ) = 2.5603804408050657
# Cost function = 0.23505001912782092
#
#
#
# ---- iteration 69 ----
# Hypothesis1: 4.28650375211926
# Error1: 0.7134962478807401
#
# Hypothesis2: 6.846884192924326
# Error2: 0.1531158070756744
#
# Hypothesis3: 9.40726463372939
# Error3: -0.40726463372939037
#
# w0 := w0 - alpha * 1/3.0 * ( 0.7134962478807401 * 1 + 0.1531158070756744 * 1 + -0.40726463372939037 * 1 +  ) = 1.7322479435972211
# w1 := w1 - alpha * 1/3.0 * ( 0.7134962478807401 * 1 + 0.1531158070756744 * 2 + -0.40726463372939037 * 3 +  ) = 2.5576862269496514
# Cost function = 0.23279527600102137
#
#
#
# ---- iteration 70 ----
# Hypothesis1: 4.289934170546872
# Error1: 0.7100658294531277
#
# Hypothesis2: 6.847620397496524
# Error2: 0.15237960250347626
#
# Hypothesis3: 9.405306624446176
# Error3: -0.40530662444617604
#
# w0 := w0 - alpha * 1/3.0 * ( 0.7100658294531277 * 1 + 0.15237960250347626 * 1 + -0.40530662444617604 * 1 +  ) = 1.7383431276973602
# w1 := w1 - alpha * 1/3.0 * ( 0.7100658294531277 * 1 + 0.15237960250347626 * 2 + -0.40530662444617604 * 3 +  ) = 2.5550049624312723
# Cost function = 0.23056216174534308
#
#
#
# ---- iteration 71 ----
# Hypothesis1: 4.2933480901286325
# Error1: 0.7066519098713675
#
# Hypothesis2: 6.848353052559904
# Error2: 0.15164694744009566
#
# Hypothesis3: 9.403358014991177
# Error3: -0.40335801499117707
#
# w0 := w0 - alpha * 1/3.0 * ( 0.7066519098713675 * 1 + 0.15164694744009566 * 1 + -0.40335801499117707 * 1 +  ) = 1.744409005594964
# w1 := w1 - alpha * 1/3.0 * ( 0.7066519098713675 * 1 + 0.15164694744009566 * 2 + -0.40335801499117707 * 3 +  ) = 2.552336585894979
# Cost function = 0.2283504688834577
#
#
#
# ---- iteration 72 ----
# Hypothesis1: 4.296745591489943
# Error1: 0.7032544085100572
#
# Hypothesis2: 6.849082177384922
# Error2: 0.15091782261507802
#
# Hypothesis3: 9.401418763279901
# Error3: -0.4014187632799011
#
# w0 := w0 - alpha * 1/3.0 * ( 0.7032544085100572 * 1 + 0.15091782261507802 * 1 + -0.4014187632799011 * 1 +  ) = 1.750445718499567
# w1 := w1 - alpha * 1/3.0 * ( 0.7032544085100572 * 1 + 0.15091782261507802 * 2 + -0.4014187632799011 * 3 +  ) = 2.5496810360803193
# Cost function = 0.22615999192829056
#
#
#
# ---- iteration 73 ----
# Hypothesis1: 4.300126754579886
# Error1: 0.6998732454201138
#
# Hypothesis2: 6.849807790660206
# Error2: 0.15019220933979405
#
# Hypothesis3: 9.399488826740525
# Error3: -0.39948882674052477
#
# w0 := w0 - alpha * 1/3.0 * ( 0.6998732454201138 * 1 + 0.15019220933979405 * 1 + -0.39948882674052477 * 1 +  ) = 1.7564534068731588
# w1 := w1 - alpha * 1/3.0 * ( 0.6998732454201138 * 1 + 0.15019220933979405 * 2 + -0.39948882674052477 * 3 +  ) = 2.547038251865361
# Cost function = 0.2239905273639241
#
#
#
# ---- iteration 74 ----
# Hypothesis1: 4.30349165873852
# Error1: 0.6965083412614801
#
# Hypothesis2: 6.850529910603881
# Error2: 0.14947008939611894
#
# Hypothesis3: 9.397568162469241
# Error3: -0.3975681624692413
#
# w0 := w0 - alpha * 1/3.0 * ( 0.6965083412614801 * 1 + 0.14947008939611894 * 1 + -0.3975681624692413 * 1 +  ) = 1.7624322104490036
# w1 := w1 - alpha * 1/3.0 * ( 0.6965083412614801 * 1 + 0.14947008939611894 * 2 + -0.3975681624692413 * 3 +  ) = 2.544408172300641
# Cost function = 0.22184187362669042
#
#
#
# ---- iteration 75 ----
# Hypothesis1: 4.306840382749645
# Error1: 0.6931596172503554
#
# Hypothesis2: 6.851248555050286
# Error2: 0.14875144494971426
#
# Hypothesis3: 9.395656727350927
# Error3: -0.39565672735092683
#
# w0 := w0 - alpha * 1/3.0 * ( 0.6931596172503554 * 1 + 0.14875144494971426 * 1 + -0.39565672735092683 * 1 +  ) = 1.768382268246992
# w1 := w1 - alpha * 1/3.0 * ( 0.6931596172503554 * 1 + 0.14875144494971426 * 2 + -0.39565672735092683 * 3 +  ) = 2.5417907366352677
# Cost function = 0.2197138310864442
#
#
#
# ---- iteration 76 ----
# Hypothesis1: 4.31017300488226
# Error1: 0.6898269951177403
#
# Hypothesis2: 6.851963741517528
# Error2: 0.14803625848247215
#
# Hypothesis3: 9.393754478152795
# Error3: -0.3937544781527951
#
# w0 := w0 - alpha * 1/3.0 * ( 0.6898269951177403 * 1 + 0.14803625848247215 * 1 + -0.3937544781527951 * 1 +  ) = 1.7743037185862909
# w1 := w1 - alpha * 1/3.0 * ( 0.6898269951177403 * 1 + 0.14803625848247215 * 2 + -0.3937544781527951 * 3 +  ) = 2.539185884336925
# Cost function = 0.21760620202801334
#
#
#
# ---- iteration 77 ----
# Hypothesis1: 4.313489602923216
# Error1: 0.6865103970767841
#
# Hypothesis2: 6.85267548726014
# Error2: 0.1473245127398597
#
# Hypothesis3: 9.391861371597065
# Error3: -0.3918613715970647
#
# w0 := w0 - alpha * 1/3.0 * ( 0.6865103970767841 * 1 + 0.1473245127398597 * 1 + -0.3918613715970647 * 1 +  ) = 1.7801966990958853
# w1 := w1 - alpha * 1/3.0 * ( 0.6865103970767841 * 1 + 0.1473245127398597 * 2 + -0.3918613715970647 * 3 +  ) = 2.536593555107129
# Cost function = 0.21551879063283122
#
#
#
# ---- iteration 78 ----
# Hypothesis1: 4.316790254203014
# Error1: 0.6832097457969857
#
# Hypothesis2: 6.853383809310143
# Error2: 0.14661619068985665
#
# Hypothesis3: 9.389977364417273
# Error3: -0.38997736441727326
#
# w0 := w0 - alpha * 1/3.0 * ( 0.6832097457969857 * 1 + 0.14661619068985665 * 1 + -0.38997736441727326 * 1 +  ) = 1.7860613467234796
# w1 := w1 - alpha * 1/3.0 * ( 0.6832097457969857 * 1 + 0.14661619068985665 * 2 + -0.38997736441727326 * 3 +  ) = 2.534013688892794
# Cost function = 0.21345140296074297
#
#
#
# ---- iteration 79 ----
# Hypothesis1: 4.320075035616274
# Error1: 0.6799249643837264
#
# Hypothesis2: 6.854088724509068
# Error2: 0.1459112754909322
#
# Hypothesis3: 9.388102413401862
# Error3: -0.388102413401862
#
# w0 := w0 - alpha * 1/3.0 * ( 0.6799249643837264 * 1 + 0.1459112754909322 * 1 + -0.388102413401862 * 1 +  ) = 1.791897797743117
# w1 := w1 - alpha * 1/3.0 * ( 0.6799249643837264 * 1 + 0.1459112754909322 * 2 + -0.388102413401862 * 3 +  ) = 2.5314462258949275
# Cost function = 0.21140384693198402
#
#
#
# ---- iteration 80 ----
# Hypothesis1: 4.323344023638045
# Error1: 0.6766559763619551
#
# Hypothesis2: 6.854790249532972
# Error2: 0.14520975046702844
#
# Hypothesis3: 9.3862364754279
# Error3: -0.38623647542789996
#
# w0 := w0 - alpha * 1/3.0 * ( 0.6766559763619551 * 1 + 0.14520975046702844 * 1 + -0.38623647542789996 * 1 +  ) = 1.7977061877617981
# w1 := w1 - alpha * 1/3.0 * ( 0.6766559763619551 * 1 + 0.14520975046702844 * 2 + -0.38623647542789996 * 3 +  ) = 2.5288911065750916
# Cost function = 0.20937593230933804
#
#
#
# ---- iteration 81 ----
# Hypothesis1: 4.3265972943368896
# Error1: 0.6734027056631104
#
# Hypothesis2: 6.855488400911981
# Error2: 0.1445115990880188
#
# Hypothesis3: 9.384379507487074
# Error3: -0.3843795074870737
#
# w0 := w0 - alpha * 1/3.0 * ( 0.6734027056631104 * 1 + 0.1445115990880188 * 1 + -0.3843795074870737 * 1 +  ) = 1.803486651725319
# w1 := w1 - alpha * 1/3.0 * ( 0.6734027056631104 * 1 + 0.1445115990880188 * 2 + -0.3843795074870737 * 3 +  ) = 2.526348271660131
# Cost function = 0.2073674706804598
#
#
#
# ---- iteration 82 ----
# Hypothesis1: 4.32983492338545
# Error1: 0.6701650766145502
#
# Hypothesis2: 6.856183195045581
# Error2: 0.14381680495441884
#
# Hypothesis3: 9.38253146670571
# Error3: -0.3825314667057107
#
# w0 := w0 - alpha * 1/3.0 * ( 0.6701650766145502 * 1 + 0.14381680495441884 * 1 + -0.3825314667057107 * 1 +  ) = 1.8092393239234958
# w1 := w1 - alpha * 1/3.0 * ( 0.6701650766145502 * 1 + 0.14381680495441884 * 2 + -0.3825314667057107 * 3 +  ) = 2.5238176621455475
# Cost function = 0.2053782754403685
#
#
#
# ---- iteration 83 ----
# Hypothesis1: 4.333056986069043
# Error1: 0.6669430139309567
#
# Hypothesis2: 6.856874648214591
# Error2: 0.1431253517854092
#
# Hypothesis3: 9.38069231036014
# Error3: -0.3806923103601392
#
# w0 := w0 - alpha * 1/3.0 * ( 0.6669430139309567 * 1 + 0.1431253517854092 * 1 + -0.3806923103601392 * 1 +  ) = 1.8149643379949123
# w1 := w1 - alpha * 1/3.0 * ( 0.6669430139309567 * 1 + 0.1431253517854092 * 2 + -0.3806923103601392 * 3 +  ) = 2.5212992192978323
# Cost function = 0.2034081617741153
#
#
#
# ---- iteration 84 ----
# Hypothesis1: 4.336263557292744
# Error1: 0.6637364427072558
#
# Hypothesis2: 6.8575627765905764
# Error2: 0.14243722340942355
#
# Hypothesis3: 9.378861995888409
# Error3: -0.37886199588840874
#
# w0 := w0 - alpha * 1/3.0 * ( 0.6637364427072558 * 1 + 0.14243722340942355 * 1 + -0.37886199588840874 * 1 +  ) = 1.8206618269312893
# w1 := w1 - alpha * 1/3.0 * ( 0.6637364427072558 * 1 + 0.14243722340942355 * 2 + -0.37886199588840874 * 3 +  ) = 2.5187928846559773
# Cost function = 0.20145694663960567
#
#
#
# ---- iteration 85 ----
# Hypothesis1: 4.339454711587266
# Error1: 0.6605452884127336
#
# Hypothesis2: 6.858247596243244
# Error2: 0.14175240375675635
#
# Hypothesis3: 9.377040480899222
# Error3: -0.3770404808992218
#
# w0 := w0 - alpha * 1/3.0 * ( 0.6605452884127336 * 1 + 0.14175240375675635 * 1 + -0.3770404808992218 * 1 +  ) = 1.8263319230815596
# w1 := w1 - alpha * 1/3.0 * ( 0.6605452884127336 * 1 + 0.14175240375675635 * 2 + -0.3770404808992218 * 3 +  ) = 2.5162986000323584
# Cost function = 0.19952444875059877
#
#
#
# ---- iteration 86 ----
# Hypothesis1: 4.342630523113918
# Error1: 0.6573694768860818
#
# Hypothesis2: 6.858929123146276
# Error2: 0.14107087685372388
#
# Hypothesis3: 9.375227723178634
# Error3: -0.37522772317863406
#
# w0 := w0 - alpha * 1/3.0 * ( 0.6573694768860818 * 1 + 0.14107087685372388 * 1 + -0.37522772317863406 * 1 +  ) = 1.8319747581557084
# w1 := w1 - alpha * 1/3.0 * ( 0.6573694768860818 * 1 + 0.14107087685372388 * 2 + -0.37522772317863406 * 3 +  ) = 2.513816307513127
# Cost function = 0.19761048855986033
#
#
#
# ---- iteration 87 ----
# Hypothesis1: 4.345791065668835
# Error1: 0.654208934331165
#
# Hypothesis2: 6.859607373181962
# Error2: 0.14039262681803777
#
# Hypothesis3: 9.373423680695089
# Error3: -0.3734236806950886
#
# w0 := w0 - alpha * 1/3.0 * ( 0.654208934331165 * 1 + 0.14039262681803777 * 1 + -0.3734236806950886 * 1 +  ) = 1.83759046322843
# w1 := w1 - alpha * 1/3.0 * ( 0.654208934331165 * 1 + 0.14039262681803777 * 2 + -0.3734236806950886 * 3 +  ) = 2.51134594945822
# Cost function = 0.19571488824248495
#
#
#
# ---- iteration 88 ----
# Hypothesis1: 4.348936412686649
# Error1: 0.6510635873133506
#
# Hypothesis2: 6.86028236214487
# Error2: 0.1397176378551297
#
# Hypothesis3: 9.37162831160309
# Error3: -0.3716283116030894
#
# w0 := w0 - alpha * 1/3.0 * ( 0.6510635873133506 * 1 + 0.1397176378551297 * 1 + -0.3716283116030894 * 1 +  ) = 1.843179168742635
# w1 := w1 - alpha * 1/3.0 * ( 0.6510635873133506 * 1 + 0.1397176378551297 * 2 + -0.3716283116030894 * 3 +  ) = 2.508887468501078
# Cost function = 0.19383747167936963
#
#
#
# ---- iteration 89 ----
# Hypothesis1: 4.352066637243713
# Error1: 0.6479333627562873
#
# Hypothesis2: 6.860954105744791
# Error2: 0.13904589425520886
#
# Hypothesis3: 9.36984157424587
# Error3: -0.3698415742458696
#
# w0 := w0 - alpha * 1/3.0 * ( 0.6479333627562873 * 1 + 0.13904589425520886 * 1 + -0.3698415742458696 * 1 +  ) = 1.8487410045128434
# w1 := w1 - alpha * 1/3.0 * ( 0.6479333627562873 * 1 + 0.13904589425520886 * 2 + -0.3698415742458696 * 3 +  ) = 2.506440807548133
# Cost function = 0.19197806444085477
#
#
#
# ---- iteration 90 ----
# Hypothesis1: 4.355181812060977
# Error1: 0.6448181879390233
#
# Hypothesis2: 6.8616226196091095
# Error2: 0.13837738039089054
#
# Hypothesis3: 9.368063427157242
# Error3: -0.3680634271572423
#
# w0 := w0 - alpha * 1/3.0 * ( 0.6448181879390233 * 1 + 0.13837738039089054 * 1 + -0.3680634271572423 * 1 +  ) = 1.854276099728479
# w1 := w1 - alpha * 1/3.0 * ( 0.6448181879390233 * 1 + 0.13837738039089054 * 2 + -0.3680634271572423 * 3 +  ) = 2.5040059097781207
# Cost function = 0.19013649377051514
#
#
#
# ---- iteration 91 ----
# Hypothesis1: 4.3582820095066
# Error1: 0.6417179904934001
#
# Hypothesis2: 6.862287919284721
# Error2: 0.1377120807152794
#
# Hypothesis3: 9.36629382906284
# Error3: -0.36629382906284036
#
# w0 := w0 - alpha * 1/3.0 * ( 0.6417179904934001 * 1 + 0.1377120807152794 * 1 + -0.36629382906284036 * 1 +  ) = 1.8597845829570903
# w1 := w1 - alpha * 1/3.0 * ( 0.6417179904934001 * 1 + 0.1377120807152794 * 2 + -0.36629382906284036 * 3 +  ) = 2.50158271864126
# Cost function = 0.18831258856911215
#
#
#
# ---- iteration 92 ----
# Hypothesis1: 4.36136730159835
# Error1: 0.6386326984016497
#
# Hypothesis2: 6.86295002023961
# Error2: 0.13704997976039035
#
# Hypothesis3: 9.36453273888087
# Error3: -0.3645327388808699
#
# w0 := w0 - alpha * 1/3.0 * ( 0.6386326984016497 * 1 + 0.13704997976039035 * 1 + -0.3645327388808699 * 1 +  ) = 1.8652665821475058
# w1 := w1 - alpha * 1/3.0 * ( 0.6386326984016497 * 1 + 0.13704997976039035 * 2 + -0.3645327388808699 * 3 +  ) = 2.499171177858324
# Cost function = 0.1865061793786948
#
#
#
# ---- iteration 93 ----
# Hypothesis1: 4.3644377600058295
# Error1: 0.6355622399941705
#
# Hypothesis2: 6.863608937864154
# Error2: 0.1363910621358464
#
# Hypothesis3: 9.362780115722478
# Error3: -0.3627801157224777
#
# w0 := w0 - alpha * 1/3.0 * ( 0.6355622399941705 * 1 + 0.1363910621358464 * 1 + -0.3627801157224777 * 1 +  ) = 1.8707222246329398
# w1 := w1 - alpha * 1/3.0 * ( 0.6355622399941705 * 1 + 0.1363910621358464 * 2 + -0.3627801157224777 * 3 +  ) = 2.4967712314196366
# Cost function = 0.1847170983668554
#
#
#
# ---- iteration 94 ----
# Hypothesis1: 4.367493456052577
# Error1: 0.6325065439474233
#
# Hypothesis2: 6.864264687472213
# Error2: 0.13573531252778714
#
# Hypothesis3: 9.36103591889185
# Error3: -0.3610359188918508
#
# w0 := w0 - alpha * 1/3.0 * ( 0.6325065439474233 * 1 + 0.13573531252778714 * 1 + -0.3610359188918508 * 1 +  ) = 1.8761516371340512
# w1 := w1 - alpha * 1/3.0 * ( 0.6325065439474233 * 1 + 0.13573531252778714 * 2 + -0.3610359188918508 * 3 +  ) = 2.4943828235840027
# Cost function = 0.18294517931113763
#
#
#
# ---- iteration 95 ----
# Hypothesis1: 4.370534460718054
# Error1: 0.6294655392819459
#
# Hypothesis2: 6.864917284302057
# Error2: 0.13508271569794328
#
# Hypothesis3: 9.359300107886058
# Error3: -0.3593001078860585
#
# w0 := w0 - alpha * 1/3.0 * ( 0.6294655392819459 * 1 + 0.13508271569794328 * 1 + -0.3593001078860585 * 1 +  ) = 1.881554945761969
# w1 := w1 - alpha * 1/3.0 * ( 0.6294655392819459 * 1 + 0.13508271569794328 * 2 + -0.3593001078860585 * 3 +  ) = 2.492005898877598
# Cost function = 0.1811902575835919
#
#
#
# ---- iteration 96 ----
# Hypothesis1: 4.373560844639567
# Error1: 0.6264391553604334
#
# Hypothesis2: 6.865566743517165
# Error2: 0.13443325648283544
#
# Hypothesis3: 9.357572642394762
# Error3: -0.3575726423947625
#
# w0 := w0 - alpha * 1/3.0 * ( 0.6264391553604334 * 1 + 0.13443325648283544 * 1 + -0.3575726423947625 * 1 +  ) = 1.8869322760212823
# ...
# Error2: 0.001991447694432935
#
# Hypothesis3: 9.005296957277041
# Error3: -0.005296957277041159
#
# w0 := w0 - alpha * 1/3.0 * ( 0.009279852665907029 * 1 + 0.001991447694432935 * 1 + -0.005296957277041159 * 1 +  ) = 2.9835114002703964
# w1 := w1 - alpha * 1/3.0 * ( 0.009279852665907029 * 1 + 0.001991447694432935 * 2 + -0.005296957277041159 * 3 +  ) = 2.007253363321123
# Cost function = 3.937976193846778e-05
#
#
#
# ---- iteration 971 ----
# Hypothesis1: 4.990764763591519
# Error1: 0.009235236408480674
#
# Hypothesis2: 6.998018126912642
# Error2: 0.001981873087357755
#
# Hypothesis3: 9.005271490233765
# Error3: -0.005271490233765164
#
# w0 := w0 - alpha * 1/3.0 * ( 0.009235236408480674 * 1 + 0.001981873087357755 * 1 + -0.005271490233765164 * 1 +  ) = 2.9835906751938905
# w1 := w1 - alpha * 1/3.0 * ( 0.009235236408480674 * 1 + 0.001981873087357755 * 2 + -0.005271490233765164 * 3 +  ) = 2.007218490146215
# Cost function = 3.900200724653382e-05
#
#
#
# ---- iteration 972 ----
# Hypothesis1: 4.990809165340106
# Error1: 0.009190834659894342
#
# Hypothesis2: 6.998027655486321
# Error2: 0.001972344513679225
#
# Hypothesis3: 9.005246145632537
# Error3: -0.005246145632536781
#
# w0 := w0 - alpha * 1/3.0 * ( 0.009190834659894342 * 1 + 0.001972344513679225 * 1 + -0.005246145632536781 * 1 +  ) = 2.9836695689744377
# w1 := w1 - alpha * 1/3.0 * ( 0.009190834659894342 * 1 + 0.001972344513679225 * 2 + -0.005246145632536781 * 3 +  ) = 2.0071837846367435
# Cost function = 3.8627876207980135e-05
#
#
#
# ---- iteration 973 ----
# Hypothesis1: 4.990853353611181
# Error1: 0.009146646388819235
#
# Hypothesis2: 6.998037138247925
# Error2: 0.0019628617520748293
#
# Hypothesis3: 9.005220922884668
# Error3: -0.0052209228846678
#
# w0 := w0 - alpha * 1/3.0 * ( 0.009146646388819235 * 1 + 0.0019628617520748293 * 1 + -0.0052209228846678 * 1 +  ) = 2.983748083444521
# w1 := w1 - alpha * 1/3.0 * ( 0.009146646388819235 * 1 + 0.0019628617520748293 * 2 + -0.0052209228846678 * 3 +  ) = 2.0071492459865965
# Cost function = 3.8257334062502056e-05
#
#
#
# ---- iteration 974 ----
# Hypothesis1: 4.990897329431117
# Error1: 0.009102670568882587
#
# Hypothesis2: 6.998046575417714
# Error2: 0.0019534245822860896
#
# Hypothesis3: 9.00519582140431
# Error3: -0.005195821404310408
#
# w0 := w0 - alpha * 1/3.0 * ( 0.009102670568882587 * 1 + 0.0019534245822860896 * 1 + -0.005195821404310408 * 1 +  ) = 2.9838262204278125
# w1 := w1 - alpha * 1/3.0 * ( 0.009102670568882587 * 1 + 0.0019534245822860896 * 2 + -0.005195821404310408 * 3 +  ) = 2.0071148733935367
# Cost function = 3.7890346383257e-05
#
#
#
# ---- iteration 975 ----
# Hypothesis1: 4.990941093821349
# Error1: 0.009058906178650794
#
# Hypothesis2: 6.998055967214886
# Error2: 0.0019440327851141248
#
# Hypothesis3: 9.005170840608422
# Error3: -0.005170840608421656
#
# w0 := w0 - alpha * 1/3.0 * ( 0.009058906178650794 * 1 + 0.0019440327851141248 * 1 + -0.005170840608421656 * 1 +  ) = 2.9839039817392172
# w1 := w1 - alpha * 1/3.0 * ( 0.009058906178650794 * 1 + 0.0019440327851141248 * 2 + -0.005170840608421656 * 3 +  ) = 2.007080666059185
# Cost function = 3.752687907363285e-05
#
#
#
# ---- iteration 976 ----
# Hypothesis1: 4.990984647798403
# Error1: 0.009015352201597437
#
# Hypothesis2: 6.9980653138575875
# Error2: 0.001934686142412545
#
# Hypothesis3: 9.005145979916772
# Error3: -0.0051459799167723475
#
# w0 := w0 - alpha * 1/3.0 * ( 0.009015352201597437 * 1 + 0.001934686142412545 * 1 + -0.0051459799167723475 * 1 +  ) = 2.9839813691849137
# w1 := w1 - alpha * 1/3.0 * ( 0.009015352201597437 * 1 + 0.001934686142412545 * 2 + -0.0051459799167723475 * 3 +  ) = 2.007046623189
# Cost function = 3.7166898364105074e-05
#
#
#
# ---- iteration 977 ----
# Hypothesis1: 4.991027992373914
# Error1: 0.008972007626086409
#
# Hypothesis2: 6.998074615562913
# Error2: 0.0019253844370865636
#
# Hypothesis3: 9.005121238751913
# Error3: -0.005121238751913282
#
# w0 := w0 - alpha * 1/3.0 * ( 0.008972007626086409 * 1 + 0.0019253844370865636 * 1 + -0.005121238751913282 * 1 +  ) = 2.984058384562397
# w1 := w1 - alpha * 1/3.0 * ( 0.008972007626086409 * 1 + 0.0019253844370865636 * 2 + -0.005121238751913282 * 3 +  ) = 2.0070127439922603
# Cost function = 3.6810370809075375e-05
#
#
#
# ---- iteration 978 ----
# Hypothesis1: 4.991071128554657
# Error1: 0.008928871445342601
#
# Hypothesis2: 6.998083872546918
# Error2: 0.0019161274530823391
#
# Hypothesis3: 9.005096616539177
# Error3: -0.005096616539177035
#
# w0 := w0 - alpha * 1/3.0 * ( 0.008928871445342601 * 1 + 0.0019161274530823391 * 1 + -0.005096616539177035 * 1 +  ) = 2.9841350296605205
# w1 := w1 - alpha * 1/3.0 * ( 0.008928871445342601 * 1 + 0.0019161274530823391 * 2 + -0.005096616539177035 * 3 +  ) = 2.0069790276820467
# Cost function = 3.6457263283774394e-05
#
#
#
# ---- iteration 979 ----
# Hypothesis1: 4.991114057342568
# Error1: 0.008885942657432366
#
# Hypothesis2: 6.998093085024614
# Error2: 0.001906914975386087
#
# Hypothesis3: 9.00507211270666
# Error3: -0.005072112706660192
#
# w0 := w0 - alpha * 1/3.0 * ( 0.008885942657432366 * 1 + 0.001906914975386087 * 1 + -0.005072112706660192 * 1 +  ) = 2.984211306259536
# w1 := w1 - alpha * 1/3.0 * ( 0.008885942657432366 * 1 + 0.001906914975386087 * 2 + -0.005072112706660192 * 3 +  ) = 2.006945473475223
# Cost function = 3.610754298119723e-05
#
#
#
# ---- iteration 980 ----
# Hypothesis1: 4.991156779734759
# Error1: 0.008843220265241314
#
# Hypothesis2: 6.998102253209982
# Error2: 0.0018977467900178624
#
# Hypothesis3: 9.005047726685206
# Error3: -0.005047726685205589
#
# w0 := w0 - alpha * 1/3.0 * ( 0.008843220265241314 * 1 + 0.0018977467900178624 * 1 + -0.005047726685205589 * 1 +  ) = 2.9842872161311367
# w1 := w1 - alpha * 1/3.0 * ( 0.008843220265241314 * 1 + 0.0018977467900178624 * 2 + -0.005047726685205589 * 3 +  ) = 2.0069120805924183
# Cost function = 3.576117740904478e-05
#
#
#
# ---- iteration 981 ----
# Hypothesis1: 4.991199296723555
# Error1: 0.008800703276444999
#
# Hypothesis2: 6.998111377315974
# Error2: 0.001888622684026231
#
# Hypothesis3: 9.005023457908392
# Error3: -0.005023457908391649
#
# w0 := w0 - alpha * 1/3.0 * ( 0.008800703276444999 * 1 + 0.001888622684026231 * 1 + -0.005023457908391649 * 1 +  ) = 2.984362761038498
# w1 := w1 - alpha * 1/3.0 * ( 0.008800703276444999 * 1 + 0.001888622684026231 * 2 + -0.005023457908391649 * 3 +  ) = 2.006878848258009
# Cost function = 3.541813438667693e-05
#
#
#
# ---- iteration 982 ----
# Hypothesis1: 4.991241609296507
# Error1: 0.008758390703492935
#
# Hypothesis2: 6.998120457554516
# Error2: 0.0018795424454838283
#
# Hypothesis3: 9.004999305812525
# Error3: -0.004999305812525279
#
# w0 := w0 - alpha * 1/3.0 * ( 0.008758390703492935 * 1 + 0.0018795424454838283 * 1 + -0.004999305812525279 * 1 +  ) = 2.9844379427363172
# w1 := w1 - alpha * 1/3.0 * ( 0.008758390703492935 * 1 + 0.0018795424454838283 * 2 + -0.004999305812525279 * 3 +  ) = 2.006845775700101
# Cost function = 3.507838204218527e-05
#
#
#
# ---- iteration 983 ----
# Hypothesis1: 4.991283718436418
# Error1: 0.008716281563581951
#
# Hypothesis2: 6.998129494136519
# Error2: 0.0018705058634811422
#
# Hypothesis3: 9.00497526983662
# Error3: -0.004975269836620555
#
# w0 := w0 - alpha * 1/3.0 * ( 0.008716281563581951 * 1 + 0.0018705058634811422 * 1 + -0.004975269836620555 * 1 +  ) = 2.9845127629708563
# w1 := w1 - alpha * 1/3.0 * ( 0.008716281563581951 * 1 + 0.0018705058634811422 * 2 + -0.004975269836620555 * 3 +  ) = 2.0068128621505097
# Cost function = 3.474188880938076e-05
#
#
#
# ---- iteration 984 ----
# Hypothesis1: 4.991325625121366
# Error1: 0.008674374878633984
#
# Hypothesis2: 6.998138487271875
# Error2: 0.0018615127281247368
#
# Hypothesis3: 9.004951349422386
# Error3: -0.004951349422386286
#
# w0 := w0 - alpha * 1/3.0 * ( 0.008674374878633984 * 1 + 0.0018615127281247368 * 1 + -0.004951349422386286 * 1 +  ) = 2.9845872234799815
# w1 := w1 - alpha * 1/3.0 * ( 0.008674374878633984 * 1 + 0.0018615127281247368 * 2 + -0.004951349422386286 * 3 +  ) = 2.006780106844746
# Cost function = 3.4408623424870585e-05
#
#
#
# ---- iteration 985 ----
# Hypothesis1: 4.991367330324728
# Error1: 0.008632669675272098
#
# Hypothesis2: 6.998147437169473
# Error2: 0.001852562830526594
#
# Hypothesis3: 9.004927544014219
# Error3: -0.00492754401421891
#
# w0 := w0 - alpha * 1/3.0 * ( 0.008632669675272098 * 1 + 0.001852562830526594 * 1 + -0.00492754401421891 * 1 +  ) = 2.9846613259932027
# w1 := w1 - alpha * 1/3.0 * ( 0.008632669675272098 * 1 + 0.001852562830526594 * 2 + -0.00492754401421891 * 3 +  ) = 2.006747509021995
# Cost function = 3.407855492515859e-05
#
#
#
# ---- iteration 986 ----
# Hypothesis1: 4.991408835015198
# Error1: 0.008591164984801836
#
# Hypothesis2: 6.998156344037193
# Error2: 0.0018436559628067783
#
# Hypothesis3: 9.004903853059188
# Error3: -0.004903853059188279
#
# w0 := w0 - alpha * 1/3.0 * ( 0.008591164984801836 * 1 + 0.0018436559628067783 * 1 + -0.004903853059188279 * 1 +  ) = 2.984735072231715
# w1 := w1 - alpha * 1/3.0 * ( 0.008591164984801836 * 1 + 0.0018436559628067783 * 2 + -0.004903853059188279 * 3 +  ) = 2.0067150679250996
# Cost function = 3.375165264379611e-05
# ---- iteration 987 ----
# Hypothesis1: 4.9914501401568145
# Error1: 0.008549859843185459
#
# Hypothesis2: 6.998165208081915
# Error2: 0.0018347919180854433
#
# Hypothesis3: 9.004880276007013
# Error3: -0.004880276007012796
#
# w0 := w0 - alpha * 1/3.0 * ( 0.008549859843185459 * 1 + 0.0018347919180854433 * 1 + -0.004880276007012796 * 1 +  ) = 2.9848084639084385
# w1 := w1 - alpha * 1/3.0 * ( 0.008549859843185459 * 1 + 0.0018347919180854433 * 2 + -0.004880276007012796 * 3 +  ) = 2.006682782800544
# Cost function = 3.3427886208470564e-05
#
#
#
# ---- iteration 988 ----
# Hypothesis1: 4.991491246708982
# Error1: 0.008508753291017968
#
# Hypothesis2: 6.998174029509526
# Error2: 0.0018259704904739493
#
# Hypothesis3: 9.00485681231007
# Error3: -0.004856812310070069
#
# w0 := w0 - alpha * 1/3.0 * ( 0.008508753291017968 * 1 + 0.0018259704904739493 * 1 + -0.004856812310070069 * 1 +  ) = 2.9848815027280575
# w1 := w1 - alpha * 1/3.0 * ( 0.008508753291017968 * 1 + 0.0018259704904739493 * 2 + -0.004856812310070069 * 3 +  ) = 2.006650652898434
# Cost function = 3.310722553824631e-05
#
#
#
# ---- iteration 989 ----
# Hypothesis1: 4.9915321556264916
# Error1: 0.008467844373508449
#
# Hypothesis2: 6.998182808524925
# Error2: 0.0018171914750748641
#
# Hypothesis3: 9.00483346142336
# Error3: -0.0048334614233596085
#
# w0 := w0 - alpha * 1/3.0 * ( 0.008467844373508449 * 1 + 0.0018171914750748641 * 1 + -0.0048334614233596085 * 1 +  ) = 2.9849541903870604
# w1 := w1 - alpha * 1/3.0 * ( 0.008467844373508449 * 1 + 0.0018171914750748641 * 2 + -0.0048334614233596085 * 3 +  ) = 2.0066186774724817
# Cost function = 3.278964084071631e-05
#
#
#
# ---- iteration 990 ----
# Hypothesis1: 4.991572867859542
# Error1: 0.008427132140457871
#
# Hypothesis2: 6.998191545332023
# Error2: 0.0018084546679766333
#
# Hypothesis3: 9.004810222804506
# Error3: -0.004810222804506381
#
# w0 := w0 - alpha * 1/3.0 * ( 0.008427132140457871 * 1 + 0.0018084546679766333 * 1 + -0.004810222804506381 * 1 +  ) = 2.9850265285737794
# w1 := w1 - alpha * 1/3.0 * ( 0.008427132140457871 * 1 + 0.0018084546679766333 * 2 + -0.004810222804506381 * 3 +  ) = 2.006586855779987
# Cost function = 3.2475102609285926e-05
#
#
#
# ---- iteration 991 ----
# Hypothesis1: 4.991613384353766
# Error1: 0.008386615646234219
#
# Hypothesis2: 6.9982002401337535
# Error2: 0.0017997598662464753
#
# Hypothesis3: 9.00478709591374
# Error3: -0.004787095913739492
#
# w0 := w0 - alpha * 1/3.0 * ( 0.008386615646234219 * 1 + 0.0017997598662464753 * 1 + -0.004787095913739492 * 1 +  ) = 2.9850985189684294
# w1 := w1 - alpha * 1/3.0 * ( 0.008386615646234219 * 1 + 0.0017997598662464753 * 2 + -0.004787095913739492 * 3 +  ) = 2.0065551870818203
# Cost function = 3.216358162038449e-05
#
#
#
# ---- iteration 992 ----
# Hypothesis1: 4.99165370605025
# Error1: 0.008346293949750283
#
# Hypothesis2: 6.99820889313207
# Error2: 0.001791106867930381
#
# Hypothesis3: 9.00476408021389
# Error3: -0.004764080213890409
#
# w0 := w0 - alpha * 1/3.0 * ( 0.008346293949750283 * 1 + 0.001791106867930381 * 1 + -0.004764080213890409 * 1 +  ) = 2.9851701632431467
# w1 := w1 - alpha * 1/3.0 * ( 0.008346293949750283 * 1 + 0.001791106867930381 * 2 + -0.004764080213890409 * 3 +  ) = 2.006523670642406
# Cost function = 3.1855048930789216e-05
#
#
#
# ---- iteration 993 ----
# Hypothesis1: 4.991693833885552
# Error1: 0.008306166114447677
#
# Hypothesis2: 6.998217504527959
# Error2: 0.0017824954720406794
#
# Hypothesis3: 9.004741175170365
# Error3: -0.004741175170364542
#
# w0 := w0 - alpha * 1/3.0 * ( 0.008306166114447677 * 1 + 0.0017824954720406794 * 1 + -0.004741175170364542 * 1 +  ) = 2.985241463062028
# w1 := w1 - alpha * 1/3.0 * ( 0.008306166114447677 * 1 + 0.0017824954720406794 * 2 + -0.004741175170364542 * 3 +  ) = 2.0064923057297053
# Cost function = 3.1549475874908536e-05
#
#
#
# ---- iteration 994 ----
# Hypothesis1: 4.991733768791733
# Error1: 0.008266231208266639
#
# Hypothesis2: 6.998226074521439
# Error2: 0.0017739254785613667
#
# Hypothesis3: 9.004718380251145
# Error3: -0.004718380251144794
#
# w0 := w0 - alpha * 1/3.0 * ( 0.008266231208266639 * 1 + 0.0017739254785613667 * 1 + -0.004718380251144794 * 1 +  ) = 2.9853124200811707
# w1 := w1 - alpha * 1/3.0 * ( 0.008266231208266639 * 1 + 0.0017739254785613667 * 2 + -0.004718380251144794 * 3 +  ) = 2.006461091615198
# Cost function = 3.1246834062134576e-05
#
#
#
# ---- iteration 995 ----
# Hypothesis1: 4.991773511696369
# Error1: 0.00822648830363093
#
# Hypothesis2: 6.998234603311566
# Error2: 0.0017653966884338956
#
# Hypothesis3: 9.004695694926765
# Error3: -0.004695694926764915
#
# w0 := w0 - alpha * 1/3.0 * ( 0.00822648830363093 * 1 + 0.0017653966884338956 * 1 + -0.004695694926764915 * 1 +  ) = 2.985383035948708
# w1 := w1 - alpha * 1/3.0 * ( 0.00822648830363093 * 1 + 0.0017653966884338956 * 2 + -0.004695694926764915 * 3 +  ) = 2.006430027573867
# Cost function = 3.094709537418521e-05
#
#
#
# ---- iteration 996 ----
# Hypothesis1: 4.991813063522575
# Error1: 0.008186936477424744
#
# Hypothesis2: 6.998243091096443
# Error2: 0.001756908903557175
#
# Hypothesis3: 9.00467311867031
# Error3: -0.004673118670309506
#
# w0 := w0 - alpha * 1/3.0 * ( 0.008186936477424744 * 1 + 0.001756908903557175 * 1 + -0.004673118670309506 * 1 +  ) = 2.9854533123048506
# w1 := w1 - alpha * 1/3.0 * ( 0.008186936477424744 * 1 + 0.001756908903557175 * 2 + -0.004673118670309506 * 3 +  ) = 2.006399112884182
# Cost function = 3.065023196252721e-05
#
#
#
# ---- iteration 997 ----
# Hypothesis1: 4.991852425189032
# Error1: 0.00814757481096784
#
# Hypothesis2: 6.998251538073214
# Error2: 0.0017484619267857937
#
# Hypothesis3: 9.004650650957396
# Error3: -0.004650650957396252
#
# w0 := w0 - alpha * 1/3.0 * ( 0.00814757481096784 * 1 + 0.0017484619267857937 * 1 + -0.004650650957396252 * 1 +  ) = 2.985523250781922
# w1 := w1 - alpha * 1/3.0 * ( 0.00814757481096784 * 1 + 0.0017484619267857937 * 2 + -0.004650650957396252 * 3 +  ) = 2.00636834682808
# Cost function = 3.0356216245755926e-05
#
#
#
# ---- iteration 998 ----
# Hypothesis1: 4.991891597610002
# Error1: 0.00810840238999777
#
# Hypothesis2: 6.998259944438082
# Error2: 0.0017400555619175861
#
# Hypothesis3: 9.004628291266162
# Error3: -0.00462829126616171
#
# w0 := w0 - alpha * 1/3.0 * ( 0.00810840238999777 * 1 + 0.0017400555619175861 * 1 + -0.00462829126616171 * 1 +  ) = 2.9855928530043987
# w1 := w1 - alpha * 1/3.0 * ( 0.00810840238999777 * 1 + 0.0017400555619175861 * 2 + -0.00462829126616171 * 3 +  ) = 2.0063377286909514
# Cost function = 3.0065020907036882e-05
#
#
#
# ---- iteration 999 ----
# Hypothesis1: 4.99193058169535
# Error1: 0.008069418304650355
#
# Hypothesis2: 6.998268310386301
# Error2: 0.0017316896136989612
#
# Hypothesis3: 9.004606039077252
# Error3: -0.004606039077252433
#
# w0 := w0 - alpha * 1/3.0 * ( 0.008069418304650355 * 1 + 0.0017316896136989612 * 1 + -0.004606039077252433 * 1 +  ) = 2.985662120588947
# w1 := w1 - alpha * 1/3.0 * ( 0.008069418304650355 * 1 + 0.0017316896136989612 * 2 + -0.004606039077252433 * 3 +  ) = 2.006307257761622
# Cost function = 2.9776618891598503e-05
# <span style='font-size: 18px;font-weight:700'>Results for Weights:</span>
# <div width='100%'' style='font-size: 15px;font-weight:500; line-height:14px'>θ(0) aka b = 2.985662120588947<br>θ(1) aka m = 2.006307257761622</div>
# <span style='font-size: 18px;font-weight:700'>Final Cost at Last Iteration:</span>
# <div width='100%'' style='font-size: 15px;font-weight:500; line-height:14px'>(Should be small #)</div>
# <div width='100%'' style='font-size: 15px;font-weight:500; line-height:14px'>Cost = 2.9776618891598503e-05</div>

# %% [markdown]
# # Logistic Regression
# <img src="./files/crossentropy.png">

# %%
import numpy as np
import math


def sigmoid(z):
    return 1.0/(1+math.exp(-z))

def crossEntropy(features, targets, weights):
    ce = 0
    for x, t in zip(features, targets):
        h = sigmoid(sum(weights*x))
        ce = ce + -1*(t*slog(h) + (1-t)*slog(1-h))
    return ce

def hypothesis(ws, x):
    return sigmoid(sum(np.dot(ws, x)))


def costFunctionLogReg(theta):
    if (y == 1):
        -1 * math.log(hypothesis(x))
    else:
        -1 * math.log(1 - hypothesis(x))


def logit(x):
    odds = sigmoid(x) / (1 - sigmoid(x))


def slog(x):
    return 0 if x == 0 else math.log(x)





features = np.array([[1, 2, 3], [1, 3, 4], [1, 4, 5],
                     [1, 5, 6], [1, 6, 7], [1, 8, 9]])
targets = np.array([0, 0, 0, 1, 1, 1])
weights = np.array([0, 0, 0])
g = np.array([0, 0, 0])
e = 0
rate = 0.020

e = crossEntropy(features, targets, weights)
print(e)
# Out:
# 4.1588830833596715
